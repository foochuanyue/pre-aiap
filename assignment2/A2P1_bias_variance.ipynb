# %% [markdown]
# ![AIAP Banner](../images/AIAP-Banner.png "AIAP Banner")

# %% [markdown]
# <h1><center>Assignment 2 - Part 1:
# <br>
# Bias-Variance Tradeoff</center></h1>

# %% [markdown]
# <h3>Name of Apprentice:</h3>
#
# ---

# %% [markdown]
# # 1. Introduction
#
# For this notebook, we will explore the bias-variance trade off. After this notebook, you should have an appreciation for what this trade off is and how it affects the models that we train.
#
#
# #### 1.1. Topics
# 1. Bias-variance trade off
# 2. Model complexity
# 3. Overfitting and underfitting
#
#
# #### 1.2. Deliverables
# 1. Jupyter notebook

# %% [markdown]
# # 2. Bias-variance trade off
#
# When developing AI/ML solutions, it is important to understand the bias-variance trade off. While it would be great to understand the definition of bias and variance (from a statistical perspective), it is mathematically involved and will take time to process. If you are interested to do so, a useful reference that you can refer to is this [lecture](https://www.youtube.com/watch?v=zrEyxfl2-a8) from Caltech. Alternatively, you can also look up articles, blog posts and/or other YouTube videos for a quick overview on the bias-variance tradeoff.

# %% [markdown]
# #### 2.1. Describe the concept of model bias.

# %% [markdown]
# #### 2.2. Describe the concept of model variance.

# %% [markdown]
# #### 2.3. Describe the concept of model complexity. Give an example of model complexity using polynomial linear models.

# %% [markdown]
# #### 2.4. Explain how the bias-variance trade-off arises when using models of increasing complexity.

# %% [markdown]
# #### 2.5. Describe what is meant by underfitting and overfitting. Link your answer to the ideas of model bias and model variance.

# %% [markdown]
# # Explore Regression and Tuning

# %% [markdown]
# Having explored the bias-variance tradeoff, we will now focus on regression and tuning.
#
# Load the '[`A2P2_regression_tuning.ipynb`](A2P2_regression_tuning.ipynb)' notebook and start working from there.

# %% [markdown]
# <h1><center>End of Assignment 2 - Part 1:<br>Bias-Variance Tradeoff</center></h1>
